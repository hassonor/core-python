# %%
import csv
import torch
import pandas as pd

# %%
Data_path = "tutors.csv"

# %%
# read the top 50 rows of the csv file into a pandas dataframe
# install Pandas library: pip3 instlal pandas
df = pd.read_csv(Data_path, nrows=50)

# %%
# display the pandas dataframe
display(df)
# Out:
#               Username                      Name Gender  \
# 0            allison57               Kyle Torres      M
# 1          hollysutton             Joseph Larsen      M
# 2             csanchez            Harold Sanchez      M
# 3        gallagherjill               Tina Gamble      M
# 4           jennifer52               Jill Zavala      M
# 5       jonathanberger            Jamie Cardenas      F
# 6          darrenchung          Cassandra Cannon      M
# 7             tbarrett              Emily Harmon      M
# 8       schmidtrebecca              Pamela Jones      M
# 9                fpaul             Debra Brennan      F
# 10         taylorfrank             Lori Richards      M
# 11              mortiz            Benjamin Reyes      M
# 12     heatherfletcher            Jessica Walker      M
# 13      andersonrobert  Mrs. Kristin Johnston MD      F
# 14           steinanna            Regina Barnett      M
# 15         kevingarcia            Edward Swanson      M
# 16              chad09               Leslie Hale      M
# 17            dproctor              Sandra Baker      M
# 18         sanchezmark               Aaron Adams      F
# 19         seanjohnson             Jeffrey Perez      M
# 20             mpierce        Christina Petersen      M
# 21             devon69           Brandy Martinez      F
# 22             pbecker           Timothy Buckley      M
# 23        nelsonashlee             Theodore Page      F
# 24              mark46            Michael Zavala      F
# 25       erichendricks             Jessica Burch      M
# 26            qfreeman              Timothy Huff      M
# 27  angelicavalenzuela        Christopher Bryant      F
# 28             angel87               Edwin Perez      M
# 29      reynoldsjoseph            Melissa Ortega      F
# 30  livingstonjennifer              Robert White      F
# 31     harrisjohnathan                Jill Davis      M
# 32    katherinechapman             Patrick Davis      F
# 33             amber50           Stephanie Smith      M
# 34             jnewton              Jerry Harris      M
# 35           jesserich            Robert Johnson      F
# 36             tracy76         Samantha Williams      F
# 37              jyoung       Kathleen Wilson DDS      M
# 38           juanparks               Ryan Campos      F
# 39          erodriguez          Jennifer Edwards      F
# 40            ysanchez          Joseph Hernandez      M
# 41            mjenkins             Dennis Baxter      F
# 42            yjenkins              Rodney Duran      M
# 43              hbooth            Jason Anderson      F
# 44     edwardsmichelle            Albert Johnson      F
# 45            yvonne58               Eric Butler      M
# 46              smccoy    Mrs. Amanda Garcia DDS      M
# 47           scottwong              Andrew Mason      F
# 48     elizabethwilson              Leslie Stout      F
# 49             kevin45           Mary Valenzuela      M
#
#                                               Address  StateZip  \
# 0                    PSC 1119, Box 1130, APO AE 90028      1754
# 1            44279 Travis Squares, Leeville, OH 63571     83318
# 2     456 Steven Loop Apt. 257, Randallbury, AR 50325      2913
# 3   85916 Gonzales Via Apt. 745, North Krystal, CO...     89730
# 4   14766 Rodriguez Haven Suite 299, Raymondmouth,...     41628
# 5              6568 Karen Park, Hammondberg, IL 26929     25030
# 6     86650 Carla Locks, North Michelleside, IN 47522      2911
# 7        378 Dana Squares, East Christopher, SD 54896     33089
# 8   8711 Bennett Pine Suite 072, South Miguel, CA ...     19549
# 9    347 Tracey Meadow Apt. 028, Kendraside, CA 85544      3890
# 10  352 Martinez Plain Apt. 426, West Christopher,...     99620
# 11  231 Peterson Ports Suite 259, North Heather, M...     68023
# 12     333 Rachel Haven Apt. 266, Ericatown, MO 53073      8178
# 13    551 Beth Dam Apt. 549, Matthewborough, PA 53120     99699
# 14       2008 Michael Drive, Lake Elizabeth, WV 32349     89406
# 15  96597 Brandy Hollow Apt. 061, Watsonstad, NM 3...     40706
# 16           10966 Miller Plains, Jasonland, HI 82433     58840
# 17       480 Crawford Valley, West Wendyton, CT 68101     83028
# 18        533 Melanie Plains, South Tiffany, MS 22158     86325
# 19   293 Cindy Forge Apt. 478, Andreborough, MI 25865     17330
# 20           79917 Pierce Hill, Katelynport, KS 44292     72742
# 21        77554 Christopher Park, Wallsfort, NY 69678     28448
# 22             32303 Wagner Mill, Davisbury, MT 07450     57094
# 23  856 Charles Knolls Suite 125, Lauraborough, NC...     98551
# 24                   Unit 7391 Box 2059, DPO AE 60930     97910
# 25  8891 Karl Overpass Suite 139, Fraziertown, FL ...      1892
# 26          4766 Brittany Springs, Rothtown, NC 46369     56228
# 27                  820 Dixon Key, New Dana, CO 38906     61481
# 28           85183 Murray Shores, Port Mark, MO 01746      2829
# 29  20350 Anderson Haven Suite 354, Jamietown, NH ...     81412
# 30  628 Joshua Spring Apt. 189, New Victoria, MA 1...     87036
# 31     2952 West Forges Apt. 519, Johnburgh, NM 75441     26550
# 32                   Unit 6650 Box 5928, DPO AE 36262     54922
# 33                   PSC 8266, Box 8933, APO AE 99294     92080
# 34  1752 Fischer Trail Suite 670, South Jill, PA 6...     59235
# 35   14193 Sosa Spurs Suite 830, Murphytown, ID 95549     88113
# 36                   PSC 6464, Box 9584, APO AP 26886     24045
# 37             5725 Ford Spring, West Laura, ME 63549     54049
# 38             5589 Andrew Forks, Port Kara, OH 12778     19757
# 39      52230 Murphy Park, South Marcusland, AL 08436     57415
# 40             99164 Peck Manor, Wilsonfurt, KY 42855     55487
# 41     193 Hanna Dam Suite 543, Melissatown, LA 58311     68058
# 42  8432 Johnson Springs Suite 123, Jamesmouth, KY...     57132
# 43  5288 Robert Gateway Apt. 632, West Jeffrey, NC...      2896
# 44      2075 Janice Forest, East Brianhaven, OR 39741     47230
# 45     70181 Villegas Key, East Matthewland, RI 15177     58558
# 46    21548 Martinez Squares, Williamsville, AZ 55770     26114
# 47           2677 Diane Ridge, East Michael, CA 22952     33798
# 48   1831 Brandt Parkways, West Manuelmouth, WA 39505     18978
# 49         595 Edwards Green, Gloriaborough, MO 58730     40731
#
#                                    Email  Sessions
# 0               milleredwin@williams.com        18
# 1   blackwellbrianna@hubbard-simmons.org        11
# 2               jeremykennedy@sparks.biz        13
# 3                thomaskristen@yahoo.com         5
# 4                    emiller@hotmail.com        20
# 5                  michael76@gardner.com         7
# 6     davisgabriella@thornton-martin.biz        16
# 7                      qryan@hotmail.com        12
# 8                 andrewsaaron@yahoo.com         2
# 9           johnrogers@peters-fisher.com        13
# 10               smithclaire@hotmail.com        13
# 11                    andrea36@yahoo.com         8
# 12             hectorwilliams@barnes.com         8
# 13                   megan16@hotmail.com         2
# 14                     sally71@yahoo.com         5
# 15              rachel53@white-wells.com        11
# 16                brandonray@hotmail.com         7
# 17                       ahall@yahoo.com         5
# 18                  julianbell@yahoo.com         9
# 19      thomasmorrison@rocha-edwards.com         1
# 20   williamsonrobert@brown-williams.org         3
# 21                      xperez@yahoo.com         3
# 22               changjennifer@yahoo.com         2
# 23                   gaustin@hotmail.com        11
# 24               stonebenjamin@gmail.com        19
# 25               griffinrhonda@simon.com        10
# 26        fullermaria@trevino-graves.com         4
# 27                      lisa70@gmail.com         6
# 28              morrisonandrew@gmail.com        19
# 29                       amy66@yahoo.com        14
# 30                    kaguilar@gmail.com        13
# 31                    miguel33@mcgee.com        19
# 32                    hmyers@hotmail.com         6
# 33                robertharris@gmail.com         3
# 34                     jmccall@yahoo.com        15
# 35                   wclark@collins.info         4
# 36                      ydavis@yahoo.com         6
# 37                 alexander06@berry.com        14
# 38                    xgomez@collins.biz         6
# 39                 jbennett@barrett.info         5
# 40             eileenbrooks@bartlett.org         8
# 41                   adrianwu@maddox.org        13
# 42              janetsimmons@hotmail.com        10
# 43             montoyanatalie@burton.com         5
# 44                       ehood@crane.com        18
# 45              kimberlyweaver@gmail.com         4
# 46              shawn19@perez-george.com         2
# 47        gjohnson@williams-johnson.info         6
# 48              jasonosborne@hotmail.com        17
# 49                   crystal62@gmail.com         7

# %%
import torch.utils.data as data_uitils
pd.to_numeric(df["Sessions"])
sessions_df = pd.DataFrame(df['Sessions'])

# creating tensor from session_df
train_tensor = torch.tensor(sessions_df['Sessions'].values)

#printing out result
print(train_tensor)
# Out:
# tensor([18, 11, 13,  5, 20,  7, 16, 12,  2, 13, 13,  8,  8,  2,  5, 11,  7,  5,
#          9,  1,  3,  3,  2, 11, 19, 10,  4,  6, 19, 14, 13, 19,  6,  3, 15,  4,
#          6, 14,  6,  5,  8, 13, 10,  5, 18,  4,  2,  6, 17,  7])
